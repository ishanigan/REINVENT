# %%
from scipy.stats import levy
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 1)
plt.plot(x, levy.pdf(x)*100)

# %%
np.random.random(1)[0]
# Out:
# 0.49158518698828024

# %%
x = np.random.random(1)[0]
sigma = levy.pdf(x)*100
sigma
# Out:
# 44.97605753485864

# %%
np.std([1, 1, 1, 1, 0.95 , 1, 1])
# Out:
# 0.017496355305594145
