# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
directories = ['Static_10', 'Static_10_2', 'Static_10_3', 'Static_10_4', 'Static_10_5', 'Static_20', 'Static_20_2', 'Static_20_3', 'Static_20_4', 'Static_20_5', 'Static_30', 'Static_30_2', 'Static_30_3', 'Static_30_4', 'Static_30_5']
#directories = ['Static_10', 'Static_20', 'Static_30', 'uncertainty-driven', 'linear_decay', 'levy_flight', 'exponential_decay', 'adaptive_100']
colors = ['r', 'r', 'r', 'r', 'r', 'g', 'g', 'g', 'g', 'g', 'b', 'b', 'b', 'b', 'b']

# %%
plt.figure()
for i, dir in enumerate(directories):
    load_dir = 'data/results/' + dir
    scores = np.load(os.path.join(load_dir,'training_log_scores.npy'))
    plt.plot(scores, label=dir, color=colors[i])
plt.legend()
plt.title('Scores')
# Out:
# Text(0.5, 1.0, 'Scores')

# %%
plt.figure()
for dir in directories:
    load_dir = 'data/results/' + dir
    valid = np.load(os.path.join(load_dir,'training_log_valid.npy'))
    plt.plot(valid, label=dir)
plt.legend()
plt.title('Smiles validity')
# Out:
# Text(0.5, 1.0, 'Smiles validity')

# %%
plt.figure()
for dir in directories:
    load_dir = 'data/results/' + dir
    sa = np.load(os.path.join(load_dir,'training_log_sa.npy'))
    plt.plot(sa, label=dir)
plt.legend()
plt.title('Synthetic Accessibility score (cite paper here)')
# Out:
# Text(0.5, 1.0, 'Synthetic Accessibility score (cite paper here)')

# %%
plt.figure()
for dir in directories:
    load_dir = 'data/results/' + dir
    novel = np.load(os.path.join(load_dir,'training_log_novel.npy'))
    plt.plot(novel, label=dir)
plt.legend()
plt.title('Novelty')
# Out:
# Text(0.5, 1.0, 'Novelty')

# %%
plt.figure()
for dir in directories[3:]:
    load_dir = 'data/results/' + dir
    sigma = np.load(os.path.join(load_dir,'training_log_sigma.npy'))
    plt.plot(sigma, label=dir)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/ishaniganguly/Code/REINVENT/Plot Results.ipynb Cell 7 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/ishaniganguly/Code/REINVENT/Plot%20Results.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> for dir in directories[3:]:
#       <a href='vscode-notebook-cell:/Users/ishaniganguly/Code/REINVENT/Plot%20Results.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a>     load_dir = 'data/results/' + dir
# ----> <a href='vscode-notebook-cell:/Users/ishaniganguly/Code/REINVENT/Plot%20Results.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a>     sigma = np.load(os.path.join(load_dir,'training_log_sigma.npy'))
#       <a href='vscode-notebook-cell:/Users/ishaniganguly/Code/REINVENT/Plot%20Results.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a>     plt.plot(sigma, label=dir)
# ...

# %%
sa = np.load(os.path.join(load_dir,'training_log_sa.npy'))
novel = np.load(os.path.join(load_dir,'training_log_novel.npy'))
valid = np.load(os.path.join(load_dir,'training_log_valid.npy'))
scores = np.load(os.path.join(load_dir,'training_log_scores.npy'))
sigma = np.load(os.path.join(load_dir,'training_log_sigmas.npy'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/ishaniganguly/Code/REINVENT/Plot Results.ipynb Cell 3 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/ishaniganguly/Code/REINVENT/Plot%20Results.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> valid = np.load(os.path.join(load_dir,'training_log_valid.npy'))
#       <a href='vscode-notebook-cell:/Users/ishaniganguly/Code/REINVENT/Plot%20Results.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> scores = np.load(os.path.join(load_dir,'training_log_scores.npy'))
# ----> <a href='vscode-notebook-cell:/Users/ishaniganguly/Code/REINVENT/Plot%20Results.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> sigma = np.load(os.path.join(load_dir,'training_log_sigmas.npy'))
#
# File ~/miniconda3/envs/connectome/lib/python3.10/site-packages/numpy/lib/npyio.py:390, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     388     own_fid = False
# ...

# %%
plt.plot(sa)

# %%
plt.plot(novel)

# %%
plt.plot(valid)

# %%
plt.plot(scores)

# %%
scores.shape
# Out:
# (10, 2, 10)
