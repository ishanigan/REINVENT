# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
results = np.load('data/logs/Scores.npy')

# %%
plt.plot(results[0, :], results[1, :])

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics
  
# Plot between -10 and 10 with .001 steps.
x_axis = np.arange(-20, 20, 0.01)
  
# Calculating mean and standard deviation
mean = 2
sd = 1

step = np.zeros(len(x_axis)) 
step[2100:2399]  = 1.0
#plt.plot(x_axis, norm.pdf(x_axis, mean, sd))
plt.plot(x_axis, step)
plt.xlabel('bandgap')
plt.ylabel('score')
plt.show()

# %%
len(np.load('qm9_all_bandgaps.npy'))
# Out:
# 6601

# %%
np.where(x_axis > 1)
# Out:
# (array([2100, 2101, 2102, ..., 3997, 3998, 3999]),)

# %%
np.where(x_axis < 4)
# Out:
# (array([   0,    1,    2, ..., 2397, 2398, 2399]),)

# %%
0.3/0.4*1
# Out:
# 0.7499999999999999
